# %%
import evaluate

# %%
rouge_metric = evaluate.load("rouge")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-125cd56b2eb1> in <module>
# ----> 1 rouge_metric = evaluate.load("rouge")
#
# /opt/conda/lib/python3.7/site-packages/evaluate/loading.py in load(path, config_name, module_type, process_id, num_process, cache_dir, experiment_id, keep_in_memory, download_config, download_mode, revision, **init_kwargs)
#     715     download_mode = DownloadMode(download_mode or DownloadMode.REUSE_DATASET_IF_EXISTS)
#     716     evaluation_module = evaluation_module_factory(
# --> 717         path, module_type=module_type, revision=revision, download_config=download_config, download_mode=download_mode
#     718     )
#     719     evaluation_cls = import_main_class(evaluation_module.module_path)
#
# ...
